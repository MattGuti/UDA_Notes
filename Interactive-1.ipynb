# %% [markdown]
# Connected to Python 3.9.6

# %%
import pandas as pd

# Define the file path
file_path = "/Users/mattgutierrez80/Downloads/NFL_Combine_Data.csv"

# Load the CSV file into a Pandas DataFrame
nfl_combine_data = pd.read_csv(file_path)

# Display first few rows
print(nfl_combine_data.head())
# Out:
#              Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0      John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1   Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2    Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3      Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4  Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
#
#    Cone  Shuttle  Year    Pfr_ID    AV                Team  Round   Pick
# 0   NaN      NaN  2000  AbraJo00  26.0       New York Jets    1.0   13.0
# 1   NaN      NaN  2000  AlexSh00  26.0    Seattle Seahawks    1.0   19.0
# 2  8.48     4.98  2000  AlfoDa20   0.0  Kansas City Chiefs    6.0  188.0
# 3  7.29     4.49  2000       NaN   0.0                 NaN    NaN    NaN
# 4  7.18     4.15  2000  AndeRa21   6.0   Carolina Panthers    1.0   23.0

# %%
import pandas as pd

# Define the file path
file_path = "/Users/mattgutierrez80/Downloads/NFL_Combine_Data.csv"

# Load the CSV file into a Pandas DataFrame
nfl_combine_data = pd.read_csv(file_path)

# Display first few rows
print(nfl_combine_data.head())
# Out:
#              Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0      John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1   Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2    Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3      Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4  Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
#
#    Cone  Shuttle  Year    Pfr_ID    AV                Team  Round   Pick
# 0   NaN      NaN  2000  AbraJo00  26.0       New York Jets    1.0   13.0
# 1   NaN      NaN  2000  AlexSh00  26.0    Seattle Seahawks    1.0   19.0
# 2  8.48     4.98  2000  AlfoDa20   0.0  Kansas City Chiefs    6.0  188.0
# 3  7.29     4.49  2000       NaN   0.0                 NaN    NaN    NaN
# 4  7.18     4.15  2000  AndeRa21   6.0   Carolina Panthers    1.0   23.0

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = df.groupby(['Year', 'Position']).mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File Untitled-1:2
#       1 # Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
# ----> 2 average_stats_per_year = df.groupby(['Year', 'Position']).mean(numeric_only=True)
#
# NameError: name 'df' is not defined

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Position']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File Untitled-1:2
#       1 # Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
# ----> 2 average_stats_per_year = nfl_combine_data.groupby(['Year', 'Position']).mean(numeric_only=True)
#       4 # Reset index for better readability
#       5 average_stats_per_year = average_stats_per_year.reset_index()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Position'

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())

average_stats_per_year
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0    2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1    2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2    2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3    2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4    2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
# ..    ...  ..        ...         ...       ...        ...        ...
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle        AV     Round        Pick
# 0    103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1    119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2    112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3    103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4    112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
# ..          ...       ...       ...       ...       ...         ...
# 335  108.882353  7.098750  4.364375  0.000000       NaN         NaN
# 336  119.375000  7.021538  4.268889  0.000000       NaN         NaN
# 337  123.380952  6.847778  4.268182  0.000000       NaN         NaN
# 338  117.000000  7.166923  4.374615  0.000000       NaN         NaN
# 339  119.918919  6.915769  4.282308  0.000000       NaN         NaN
#
# [340 rows x 13 columns]

# %%
average_stats_per_year
# Out:
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0    2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1    2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2    2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3    2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4    2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
# ..    ...  ..        ...         ...       ...        ...        ...
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle        AV     Round        Pick
# 0    103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1    119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2    112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3    103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4    112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
# ..          ...       ...       ...       ...       ...         ...
# 335  108.882353  7.098750  4.364375  0.000000       NaN         NaN
# 336  119.375000  7.021538  4.268889  0.000000       NaN         NaN
# 337  123.380952  6.847778  4.268182  0.000000       NaN         NaN
# 338  117.000000  7.166923  4.374615  0.000000       NaN         NaN
# 339  119.918919  6.915769  4.282308  0.000000       NaN         NaN
#
# [340 rows x 13 columns]

# %%
print(average_stats_per_year)
# Out:
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0    2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1    2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2    2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3    2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4    2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
# ..    ...  ..        ...         ...       ...        ...        ...
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle        AV     Round        Pick
# 0    103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1    119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2    112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3    103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4    112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
# ..          ...       ...       ...       ...       ...         ...
# 335  108.882353  7.098750  4.364375  0.000000       NaN         NaN
# 336  119.375000  7.021538  4.268889  0.000000       NaN         NaN
# 337  123.380952  6.847778  4.268182  0.000000       NaN         NaN
# 338  117.000000  7.166923  4.374615  0.000000       NaN         NaN
# 339  119.918919  6.915769  4.282308  0.000000       NaN         NaN
#
# [340 rows x 13 columns]

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())

print(average_stats_per_year.tail())
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle   AV  Round  Pick
# 335  108.882353  7.098750  4.364375  0.0    NaN   NaN
# 336  119.375000  7.021538  4.268889  0.0    NaN   NaN
# 337  123.380952  6.847778  4.268182  0.0    NaN   NaN
# 338  117.000000  7.166923  4.374615  0.0    NaN   NaN
# 339  119.918919  6.915769  4.282308  0.0    NaN   NaN

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())

print(average_stats_per_year.tail())

average_stats_per_year.to_csv('average_stats_per_year.csv', index=False)
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle   AV  Round  Pick
# 335  108.882353  7.098750  4.364375  0.0    NaN   NaN
# 336  119.375000  7.021538  4.268889  0.0    NaN   NaN
# 337  123.380952  6.847778  4.268182  0.0    NaN   NaN
# 338  117.000000  7.166923  4.374615  0.0    NaN   NaN
# 339  119.918919  6.915769  4.282308  0.0    NaN   NaN
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File Untitled-1:12
#       8 print(average_stats_per_year.head())
#      10 print(average_stats_per_year.tail())
# ---> 12 average_stats_per_year.to_csv('average_stats_per_year.csv', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 30] Read-only file system: 'average_stats_per_year.csv'

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_year = average_stats_per_year.reset_index()

# Display the result
print(average_stats_per_year.head())

print(average_stats_per_year.tail())

average_stats_per_year.to_csv('/Users/mattgutierrez80/Downloads/average_stats_per_year.csv', index=False)
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle   AV  Round  Pick
# 335  108.882353  7.098750  4.364375  0.0    NaN   NaN
# 336  119.375000  7.021538  4.268889  0.0    NaN   NaN
# 337  123.380952  6.847778  4.268182  0.0    NaN   NaN
# 338  117.000000  7.166923  4.374615  0.0    NaN   NaN
# 339  119.918919  6.915769  4.282308  0.0    NaN   NaN

# %%
import pandas as pd

# Load the dataset
file_path = "/Users/mattgutierrez80/Downloads/NFL_Combine_Data.csv"
df = pd.read_csv(file_path)

# Group by 'Year' and compute the mean for numerical columns
average_stats_per_year = df.groupby('Year').mean(numeric_only=True).reset_index()

# Display the first few rows
print(average_stats_per_year.head())

# Save the results (optional)
output_path = "/Users/mattgutierrez80/Downloads/average_stats_per_year.csv"
average_stats_per_year.to_csv(output_path, index=False)
print(f"File saved successfully at: {output_path}")
# Out:
#    Year         Ht          Wt     Forty   Vertical  BenchReps   BroadJump  \
# 0  2000  73.501558  240.305296  4.806141  32.535088  20.640000  111.758475
# 1  2001  73.663551  244.492212  4.826045  34.178404  20.528736  112.427907
# 2  2002  73.778125  242.521875  4.784286  33.609053  21.517241  113.545833
# 3  2003  74.012539  249.692790  4.831912  32.835526  21.733333  112.515419
# 4  2004  73.958209  246.110448  4.806677  32.605372  22.270833  112.930041
#
#        Cone   Shuttle        AV     Round        Pick
# 0  7.307192  4.389703  5.336449  3.711111  105.766667
# 1  7.469511  4.375489  5.903427  3.865672  110.661692
# 2  7.281719  4.328404  5.578125  3.794872  113.430769
# 3  7.481744  4.423454  5.680251  3.834951  114.033981
# 4  7.407839  4.324439  5.695522  3.879227  112.458937
# File saved successfully at: /Users/mattgutierrez80/Downloads/average_stats_per_year.csv

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_pos = average_stats_per_pos.reset_index()

# Display the result
print(average_stats_per_pos.head())

print(average_stats_per_pos.tail())

average_stats_per_year.to_csv('/Users/mattgutierrez80/Downloads/average_stats_per_pos.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File Untitled-1:5
#       2 average_stats_per_year = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)
#       4 # Reset index for better readability
# ----> 5 average_stats_per_pos = average_stats_per_pos.reset_index()
#       7 # Display the result
#       8 print(average_stats_per_pos.head())
#
# NameError: name 'average_stats_per_pos' is not defined

# %%
# Group by 'Year' and 'Position' (Combine Class) and compute the mean for numerical stats
average_stats_per_pos = nfl_combine_data.groupby(['Year', 'Pos']).mean(numeric_only=True)

# Reset index for better readability
average_stats_per_pos = average_stats_per_pos.reset_index()

# Display the result
print(average_stats_per_pos.head())

print(average_stats_per_pos.tail())

average_stats_per_year.to_csv('/Users/mattgutierrez80/Downloads/average_stats_per_pos.csv', index=False)
# Out:
#    Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 0  2000   C  75.250000  292.500000  5.142500  30.333333  21.000000
# 1  2000  CB  70.911765  192.323529  4.519412  36.020000  14.476190
# 2  2000  DE  75.476190  272.523810  4.903000  32.468750  24.714286
# 3  2000  DT  75.000000  300.518519  5.083704  29.571429  26.000000
# 4  2000  FB  72.200000  243.300000  4.812000  32.000000  22.333333
#
#     BroadJump      Cone   Shuttle        AV     Round        Pick
# 0  103.333333  7.525000  4.575000  5.250000  2.000000   60.000000
# 1  119.333333  6.950435  4.147727  5.000000  3.560000   98.840000
# 2  112.250000  7.441429  4.460000  8.000000  3.333333   93.166667
# 3  103.190476  7.608421  4.603684  5.074074  4.000000  111.875000
# 4  112.000000  7.405714  4.484286  1.300000  5.142857  150.142857
#      Year Pos         Ht          Wt     Forty   Vertical  BenchReps  \
# 335  2018  QB  74.736842  220.631579  4.855294  29.529412  16.000000
# 336  2018  RB  71.419355  218.483871  4.589231  34.321429  17.241379
# 337  2018   S  72.962963  201.925926  4.525000  36.068182  17.142857
# 338  2018  TE  76.117647  251.705882  4.740769  33.038462  18.076923
# 339  2018  WR  73.159091  203.295455  4.518108  34.565789  14.500000
#
#       BroadJump      Cone   Shuttle   AV  Round  Pick
# 335  108.882353  7.098750  4.364375  0.0    NaN   NaN
# 336  119.375000  7.021538  4.268889  0.0    NaN   NaN
# 337  123.380952  6.847778  4.268182  0.0    NaN   NaN
# 338  117.000000  7.166923  4.374615  0.0    NaN   NaN
# 339  119.918919  6.915769  4.282308  0.0    NaN   NaN

# %%
import pandas as pd

# Load the dataset
file_path = "/Users/mattgutierrez80/Downloads/NFL_Combine_Data.csv"
df = pd.read_csv(file_path)

# Group by 'Year' and compute the mean for numerical columns
average_stats_per_year = df.groupby('Year').mean(numeric_only=True).reset_index()

# Display the first few rows
print(average_stats_per_year.head())

# Save the results (optional)
output_path = "/Users/mattgutierrez80/Downloads/average_stats_per_year.csv"
average_stats_per_year.to_csv(output_path, index=False)
print(f"File saved successfully at: {output_path}")
# Out:
#    Year         Ht          Wt     Forty   Vertical  BenchReps   BroadJump  \
# 0  2000  73.501558  240.305296  4.806141  32.535088  20.640000  111.758475
# 1  2001  73.663551  244.492212  4.826045  34.178404  20.528736  112.427907
# 2  2002  73.778125  242.521875  4.784286  33.609053  21.517241  113.545833
# 3  2003  74.012539  249.692790  4.831912  32.835526  21.733333  112.515419
# 4  2004  73.958209  246.110448  4.806677  32.605372  22.270833  112.930041
#
#        Cone   Shuttle        AV     Round        Pick
# 0  7.307192  4.389703  5.336449  3.711111  105.766667
# 1  7.469511  4.375489  5.903427  3.865672  110.661692
# 2  7.281719  4.328404  5.578125  3.794872  113.430769
# 3  7.481744  4.423454  5.680251  3.834951  114.033981
# 4  7.407839  4.324439  5.695522  3.879227  112.458937
# File saved successfully at: /Users/mattgutierrez80/Downloads/average_stats_per_year.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot average 40-Yard Dash time per year
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='40-Yard Dash', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Average 40-Yard Dash Time")
plt.title("NFL Combine: Average 40-Yard Dash Time Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-16-df379c57c766>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='40-Yard Dash', marker='o', ci=None)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File Untitled-1:6
#       4 # Plot average 40-Yard Dash time per year
#       5 plt.figure(figsize=(10, 5))
# ----> 6 sns.lineplot(data=average_stats_per_pos, x='Year', y='40-Yard Dash', marker='o', ci=None)
#       8 plt.xlabel("Year")
#       9 plt.ylabel("Average 40-Yard Dash Time")
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `40-Yard Dash` for `y`. An entry with this name does not appear in `data`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot average 40-Yard Dash time per year
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Forty', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Average 40-Yard Dash Time")
plt.title("NFL Combine: Average 40-Yard Dash Time Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-17-da45762463a3>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Forty', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='BenchReps', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Average Bench Press Reps")
plt.title("NFL Combine: Average Bench Press Reps Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-18-fd82270de565>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='BenchReps', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Ht', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Height (inches)")
plt.title("NFL Combine: Average Height Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-19-89fc1c0aa61a>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Ht', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Vertical', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Vertical Jump (inches)")
plt.title("NFL Combine: Average Vertical Jump Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-20-10d0bc6e1111>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Vertical', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='BroadJump', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Broad Jump (inches)")
plt.title("NFL Combine: Average Broad Jump Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-21-9ff841fd7071>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='BroadJump', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Cone', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Cone Drill Time (seconds)")
plt.title("NFL Combine: Average Cone Drill Time Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-22-9ea4061f30a5>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Cone', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Shuttle', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Shuttle Drill Time (seconds)")
plt.title("NFL Combine: Average Shuttle Drill Time Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-23-671ddce38af1>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Shuttle', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Wt', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Weight (lbs)")
plt.title("NFL Combine: Average Weight Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-24-7331d2275067>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Wt', marker='o', ci=None)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=average_stats_per_pos, x='Year', y='Ht', marker='o', ci=None)

plt.xlabel("Year")
plt.ylabel("Height (inches)")
plt.title("NFL Combine: Average Height Over the Years")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-25-89fc1c0aa61a>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=average_stats_per_pos, x='Year', y='Ht', marker='o', ci=None)
